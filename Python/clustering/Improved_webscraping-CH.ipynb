# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from datetime import datetime
from arsenic import get_session
from arsenic.browsers import Firefox
from arsenic.services import Geckodriver
import asyncio
from selenium import webdriver

# disable arsenic logging to stdout
import structlog
import logging

logger = logging.getLogger()
logger.setLevel(logging.WARN)
structlog.configure(logger_factory=lambda: logger)

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
#driver_path = "./programs/geckodriver.exe"
# driver_path = 'C:\programs\geckodriver.exe'
# # Linux
# # driver_path = "./drivers/linux/geckodriver"
# # driver_path = "/usr/bin/geckodriver"

# options = {
#   'moz:firefoxOptions': {
#     # if you want it to be headless
#     'args': ['-headless'],
#     'log': {'level': 'warn'},
#     # Needed for windows / non-default firefox install
#     'binary': 'C:\\Program Files\\Mozilla Firefox\\firefox.exe'
#   }
# }

driver_path = r"./drivers/geckodriver"
# driver = webdriver.Firefox(executable_path=driver_path)
# driver = webdriver.Chrome(executable_path=driver_path)
driver = webdriver.Chrome()

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 1000

## Number of browser instances to use
n = 3

pages = list(range(0, postings, 10))

state = {
  'lock': asyncio.Lock(),
  'ids': set(),
  'n': 0
}
             
async def get_jobs(url, pages, state):
  data = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for i in pages:
      await session.get(url + "&start=" + str(i))
      jobs = await session.get_elements("[class='job_seen_beacon']")

      for job in jobs:
        result_html = await job.get_property('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')

        liens = await job.get_elements("a")
        link = await liens[0].get_attribute("href")

        title = soup.select('.jobTitle')[0].get_text().strip()
        try:
          company = soup.select('.companyName')[0].get_text().strip()
        except:
          continue
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
            
        Id = f"{title}{company}{location}{rating}{date}{salary}{description}"
        dupe = False
        async with state['lock']:
          if Id in state['ids']:
            dupe = True
          else:
            state['ids'].add(Id)
            state['n'] = state['n'] + 1
            print("Job number {0:4d} added - {1:s}".format(state['n'],title))
        if dupe:
          continue

        data.append({
          'Title': title,
          "Company": company,
          'Location': location,
          'Rating': rating,
          'Date': date,
          "Salary": salary,
          "Description": description,
          "Links": link
        })

        # print("Job number {0:4d} added - {1:s}".format(jn,title))
      i = i + 10
  return data

tasks = [asyncio.create_task(get_jobs(url, p, state)) for p in np.array_split(pages, n)]
dataframe = pd.DataFrame([j for task in tasks for j in await task])
# Out:
# Job number    1 added - AI Engineer
# Job number    2 added - Principal Marketing Data Scientist
# Job number    3 added - Senior Data Analyst - UHC M&R Part D - Minnetonka, MN or Remote USA
# Job number    4 added - Machine Learning Engineer
# Job number    5 added - Instructor, Data Science
# Job number    6 added - Machine Learning Engineer - Platform
# Job number    7 added - Applied ML Engineer
# Job number    8 added - Associate Director, Clinical Data Science, Spotfire/R (Remote)
# Job number    9 added - Senior Data Scientist (AI/ML)
# Job number   10 added - Staff Data Scientist
# Job number   11 added - Senior Data Scientist
# Job number   12 added - Data Scientist
# Job number   13 added - AI Engineer
# Job number   14 added - DATA SCIENTISTS
# Job number   15 added - Data and Technology Leader – IBM Watson Advertising
# Job number   16 added - Senior Data Scientist/ Data Modeler ( Only USC/ GC/ EAD)
# Job number   17 added - Senior Data Scientist (Remote Friendly)
# Job number   18 added - Data Scientist
# Job number   19 added - Manager, Data Solutions
# Job number   20 added - Senior Data Analyst
# Job number   21 added - Data Scientist, Marketing & Online (Remote)
# Job number   22 added - Data Scientist
# Job number   23 added - Sr. Energy Storage Machine Learning Engineer - REMOTE
# Job number   24 added - Analyst I, Data Science
# Job number   25 added - Staff Machine Learning Scientist
# Job number   26 added - Data Scientist (Remote)
# Job number   27 added - Senior/Principal Statistical Programmer (Remote)
# Job number   28 added - Machine Learning Engineer
# Job number   29 added - Data Scientist - NLP
# Job number   30 added - Dir. of Machine Learning
# Job number   31 added - Principal Statistical Programmer FSP (Remote)
# Job number   32 added - Data Scientist
# Job number   33 added - Senior Machine Learning Software Engineer - Remote
# Job number   34 added - Data Scientist
# Job number   35 added - Remote Data Scientist / Senior Data Scientist
# Job number   36 added - Remote Sensing Data Scientist
# Job number   37 added - Java NLP Developer (14937)
# Job number   38 added - Senior Data Scientist
# Job number   39 added - Director, Statistical Programming
# Job number   40 added - Data Scientist or Statistician
# Job number   41 added - Senior Data Scientist
# Job number   42 added - Junior Data Scientist
# Job number   43 added - Arity - Data Scientist Lead Consultant
# Job number   44 added - Staff Data Scientist
# Job number   45 added - Data Scientist Co-Op (Spring 2023)
# Job number   46 added - Research Scientist (Systems Analyst)-Enterprise Systems & Data Analysis Staff
# Job number   47 added - Senior Data Scientist
# Job number   48 added - Software Engineer (AI/ML)
# Job number   49 added - Senior FRM Analyst – Actuarial or Data Scientist
# Job number   50 added - Data Scientist - Climate Risk Modeling
# Job number   51 added - Senior Machine Learning Engineer – AI/ML (Remote Option*)
# Job number   52 added - Data Analyst - Remote
# Job number   53 added - Machine Learning Engineer (Summer/Fall 2023)
# Job number   54 added - Lead Data Scientist - Recommender Systems
# Job number   55 added - AWS Sagemaker Data Scientist/ ML Specialist
# Job number   56 added - Data Scientist
# Job number   57 added - Senior Associate, Data Science (R-13261)
# Job number   58 added - Data Engineer
# Job number   59 added - Sr. Business Data Analyst
# Job number   60 added - Senior Data Analyst
# Job number   61 added - Senior Data Scientist
# Job number   62 added - Data Contributor - US
# Job number   63 added - Data Scientist|New brunswick,NJ
# Job number   64 added - Sr Data Scientist
# Job number   65 added - AVCOM - Data Scientist
# Job number   66 added - Data Scientist
# Job number   67 added - Data Scientist
# Job number   68 added - Data Analyst
# Job number   69 added - Data Scientist
# Job number   70 added - Data Scientist
# Job number   71 added - Data Scientist, Product
# Job number   72 added - Data Scientist - 100% Remote
# Job number   73 added - Data Scientist
# Job number   74 added - Research Scientist I (Institute of Data Engineering and Science)
# Job number   75 added - Senior Data Scientist
# Job number   76 added - Data Scientist, Consultant
# Job number   77 added - Tapad - Lead Data Scientist - Remote
# Job number   78 added - AI/ML Applied Scientist - fully remote in US, EST working hours - no transfer or sponsorship
# Job number   79 added - Machine Learning(ML) Engineer
# Job number   80 added - Junior AI/ML Software Developer
# Job number   81 added - Lead Data Scientist
# Job number   82 added - Senior Data Scientist
# Job number   83 added - Senior Data Scientist
# Job number   84 added - Senior Data Scientist, Insights & Analytics
# Job number   85 added - Sr. Data Analyst
# Job number   86 added - Sr Data Analyst - Provider Network
# Job number   87 added - Data Science Tech Lead
# Job number   88 added - Senior Data Scientist (REMOTE)
# Job number   89 added - Jr. Data Scientist
# Job number   90 added - (5) Data Analyst / Data Scientist
# Job number   91 added - Oraacle Data Scientist
# Job number   92 added - Data Scientist
# Job number   93 added - Nurse Data Miner
# Job number   94 added - People Analytics Data Scientist
# Job number   95 added - Data Scientist II
# Job number   96 added - Statistician and Data Scientist, Junior
# Job number   97 added - Data Scientist
# Job number   98 added - Data Scientist
# Job number   99 added - Sr. Data Analyst
# Job number  100 added - Data Scientist
# Job number  101 added - Data Scientist
# Job number  102 added - Digital Pathology Machine Learning Scientist
# Job number  103 added - Machine Learning Engineer - All Levels (REMOTE)
# Job number  104 added - Clinical Data Abstracter
# Job number  105 added - Data Integration Specialist
# Job number  106 added - Senior Data Scientist
# Job number  107 added - Senior Data Scientist (Remote)
# Job number  108 added - Data Scientist (Remote)
# Job number  109 added - Data Scientist
# Job number  110 added - Quantitative, Qualitative, and/or Mixed Methods Statisticians
# Job number  111 added - Machine Learning Engineer
# Job number  112 added - Data Scientist
# Job number  113 added - Analyst II, Ancillary Revenue Data Scientist (Remote Work Assignment Available)
# Job number  114 added - Sr. Data Scientist
# Job number  115 added - Data Science Graduate Research Assistant
# Job number  116 added - RE-IGNITE Return to Work Opportunity: Data Engineer
# Job number  117 added - Data Scientist (Remote)
# Job number  118 added - Lead Data Scientist
# Job number  119 added - Senior Data Analyst
# Job number  120 added - Machine Learning Engineer
# Job number  121 added - VP, Data Science
# Job number  122 added - Cybersecurity Data Science Lead
# Job number  123 added - Machine Learning Engineer
# Job number  124 added - Staff Data Scientist - Retail
# Job number  125 added - Senior Data Scientist (Data Analytics)
# Job number  126 added - Data Scientist
# Job number  127 added - Data Scientist
# Job number  128 added - NLP Data Scientist
# Job number  129 added - Data Scientist - remote
# Job number  130 added - Data Scientist
# Job number  131 added - Sr. Data Scientist
# Job number  132 added - Data Scientist
# Job number  133 added - Data Scientist
# Job number  134 added - Data Scientist
# Job number  135 added - Sales Engineer - Data & Analytics
# Job number  136 added - Data Engineer/Data Scientist
# Job number  137 added - Sr. Data Analyst
# Job number  138 added - Data Scientist
# Job number  139 added - Data Scientists
# Job number  140 added - Data Analyst (Remote)
# Job number  141 added - Co-Op, Machine Learning Software Engineer
# Job number  142 added - Product Management Data Scientist
# Job number  143 added - Tapad - Senior Data Scientist (Remote)
# Job number  144 added - Data Scientist Sr (Level 3)
# Job number  145 added - Junior Machine Learning Engineer
# Job number  146 added - Data Scientist - Role can be remote
# Job number  147 added - Graduate IT Program - Information Technology, Cybersecurity and Data Science (Remote)
# Job number  148 added - Research Scientist - Machine Learning for Computer Vision
# Job number  149 added - Data Scientist
# Job number  150 added - Data Scientist III(SQL,Oracle,Business Solutions,Data Mining,Pharma)
# Job number  151 added - Data Scientist (C2C not available)
# Job number  152 added - Data Scientist, Tooling
# Job number  153 added - Data Scientist
# Job number  154 added - Training and Placement in Data Science and Business Analyst on W2
# Job number  155 added - Data Visualization Specialist
# Job number  156 added - Data Scientist - 3 positions - 100% remote
# Job number  157 added - ML Engineer
# Job number  158 added - Data Scientist
# Job number  159 added - Data Scientist
# Job number  160 added - Remote Data Scientist
# Job number  161 added - Healthcare Data Scientist
# Job number  162 added - Conversational AI chatbot Engineer
# Job number  163 added - Senior Data Scientist | Bankrate
# Job number  164 added - Machine Learning Engineer: Deep Reinforcement Learning
# Job number  165 added - AI/ML Engineer
# Job number  166 added - Data Scientist -- Principal
# Job number  167 added - Data Scientist - Remote
# Job number  168 added - Geospatial Machine Learning Software Develope
# Job number  169 added - Software Engineer - AI Team
# Job number  170 added - Senior Data Engineer (Python & ML)
# Job number  171 added - Sr. Data Analyst
# Job number  172 added - Senior Python Backend Engineer - AI Start Up
# Job number  173 added - Financial Crimes - Fraud Data Scientist - Manager
# Job number  174 added - Data Scientist (NBA)
# Job number  175 added - Data Scientist
# Job number  176 added - Data Scientist
# Job number  177 added - MACHINE LEARNING DATA SCIENTIST - PYTHON AND R
# Job number  178 added - Data Scientist
# Job number  179 added - Data Scientist
# Job number  180 added - Metadata Technologist - Al and Machine Learning
# Job number  181 added - Statistician and Dissertation Consultant
# Job number  182 added - Data Scientist/Applied Researcher
# Job number  183 added - Data Scientist
# Job number  184 added - Machine Learning Engineer Sr
# Job number  185 added - Statistician
# Job number  186 added - Developer Advocate, Quarto
# Job number  187 added - Backend Engineer - Data Systems
# Job number  188 added - AI Engineer (Python)
# Job number  189 added - Senior Data Scientist I (Remote)
# Job number  190 added - Senior Healthcare Data Analyst
# Job number  191 added - AI Software Engineer
# Job number  192 added - Senior Data Analyst
# Job number  193 added - Data Scientist
# Job number  194 added - Data Scientist - Opportunity for Working Remotely Miami, FL
# Job number  195 added - Director, Statistical Programming
# Job number  196 added - Junior Data Scientist - Remote US
# Job number  197 added - Staff Data Scientist
# Job number  198 added - Senior Data Scientist (Remote)
# Job number  199 added - Principal Statistician
# Job number  200 added - Senior Data Scientist
# Job number  201 added - Data Scientist co op (Spring/Summer 2023)
# Job number  202 added - Data Scientist, Analytics II #0000
# Job number  203 added - data scientist sr- People Analytics (Remote)
# Job number  204 added - Data Scientist
# Job number  205 added - Data Scientist
# Job number  206 added - Data Analytics & Reporting Analyst
# Job number  207 added - Principal Data Scientist
# Job number  208 added - Senior Data Analyst
# Job number  209 added - Pharmaceutical/Biotech Market Research Data Scientist
# Job number  210 added - Principal Data Scientist
# Job number  211 added - Data Science Statistician - Gabuzda Lab
# Job number  212 added - Junior Auditor – Telecom Billing
# Job number  213 added - Principal Product Data Scientist
# Job number  214 added - Support Scientist - Earth System Model Regional Physics & Data Assimilation Development
# Job number  215 added - Principal Applied Scientist - Machine Learning, SCOT - Fulfillment By Amazon
# Job number  216 added - Senior Data Analyst
# Job number  217 added - Data Scientist
# Job number  218 added - Data Scientist I
# Job number  219 added - Data Scientist
# Job number  220 added - Data Scientist, Finance
# Job number  221 added - Data Scientist
# Job number  222 added - Data Scientist (100% Remote) PERM AMICA
# Job number  223 added - Data Scientist (Brain-Computer Interface Team)
# Job number  224 added - Data Scientist
# Job number  225 added - Data Scientist, CV/NLP
# Job number  226 added - Sr Associate Data Scientist (REMOTE)
# Job number  227 added - Data Scientist
# Job number  228 added - Software Engineer, Machine Learning Foundation
# Job number  229 added - Data Scientist (AI/ML, AWS)
# Job number  230 added - Consumer Credit Data Scientist (remote)
# Job number  231 added - Senior Data Scientist
# Job number  232 added - Sr Data Scientist
# Job number  233 added - Director of Data Science & Analytics (Virtual/Remote)
# Job number  234 added - Senior Applied Scientist - NLP
# Job number  235 added - Computational and Environmental Data Science Specialist
# Job number  236 added - Senior Data Analyst
# Job number  237 added - Senior Machine Learning Engineer
# Job number  238 added - Senior Data Scientist (Remote)
# Job number  239 added - Principal Sampling Statistician
# Job number  240 added - Data Science Engineer II Onlife Health
# Job number  241 added - Data Engineer - Jumpstart
# Job number  242 added - Data Architect
# Job number  243 added - Data Scientist
# Job number  244 added - Sr. Clinical Data Scientist
# Job number  245 added - Data Scientist
# Job number  246 added - Data Scientist
# Job number  247 added - Data Scientist
# Job number  248 added - Data Scientist
# Job number  249 added - Data Scientist and Data Analytics
# Job number  250 added - Data Scientist
# Job number  251 added - Data Scientist - REMOTE
# Job number  252 added - Data Scientist / Numerical Simulation Engineer
# Job number  253 added - Healthcare Data Scientist
# Job number  254 added - Data Scientist
# Job number  255 added - Data Scientist
# Job number  256 added - Data Scientist V, Marketplaces Personalization (Remote)
# Job number  257 added - Senior Data Scientist, Safety Insights
# Job number  258 added - Staff Data Scientist, Feeds Ranking Analytics
# Job number  259 added - Data Analyst (Remote Eligible)
# Job number  260 added - Machine Learning Engineer
# Job number  261 added - Senior Data Scientist
# Job number  262 added - Medical Imaging Research Data Assistant - Picture Health
# Job number  263 added - Senior Data Scientist
# Job number  264 added - Machine Learning Engineer (Biotech)
# Job number  265 added - Director of AI, Machine Learning, Data Science SaaS solutions
# Job number  266 added - Backend Software Engineer, AI & Machine Learning - Grafana Ops
# Job number  267 added - Data Scientist
# Job number  268 added - Software Engineer - Machine Learning (Remote)
# Job number  269 added - Data Scientist - Precision Motion
# Job number  270 added - Data Scientist (Remote)
# Job number  271 added - Senior Data Scientist I
# Job number  272 added - Senior Data Scientist (Growth)
# Job number  273 added - Data Scientist
# Job number  274 added - Hiring for Data Scientist remote position :: Fulltime
# Job number  275 added - Product Data Scientist
# Job number  276 added - HEALTHCARE DATA SCIENTIST, FCH - ENTERPRISE ANALYTICS
# Job number  277 added - Senior Data Scientist
# Job number  278 added - VP, Engineering (Core Services, Data, & AI/ML)
# Job number  279 added - Staff Data Scientist, DNA Products
# Job number  280 added - Sr Statistical Programmer
# Job number  281 added - Sr Data Scientist
# Job number  282 added - Statistician
# Job number  283 added - Senior Data Scientist - Inference, Payments
# Job number  284 added - Machine Learning Engineer
# Job number  285 added - Data Scientist (Remote Opportunity)
# Job number  286 added - Data Analyst - Sr Specialist
# Job number  287 added - Machine Learning Engineer
# Job number  288 added - Retail Data Scientist
# Job number  289 added - Data Scientist - Remote
# Job number  290 added - Data Scientist, Product Analytics
# Job number  291 added - Release Train Engineer, Data & AI
# Job number  292 added - Data Scientist
# Job number  293 added - Data Scientist (Mid Level)
# Job number  294 added - Data Review Associate Scientist
# Job number  295 added - Data Scientist - Professional Services AI
# Job number  296 added - Data Scientist - Analytics
# Job number  297 added - Sr. Data Scientist
# Job number  298 added - Data Scientist
# Job number  299 added - Data Scientist
# Job number  300 added - Data Science/Analytics - New Graduate
# Job number  301 added - Data Scientist - Customer Behavior Modeling
# Job number  302 added - Environmental Statistician
# Job number  303 added - Senior Data Analyst
# Job number  304 added - Machine Learning Engineer
# Job number  305 added - Data Scientist
# Job number  306 added - Data Scientist
# Job number  307 added - ML Engineer
# Job number  308 added - Senior Associate, Data Science (R-13261)
# Job number  309 added - Engineer - Machine Learning
# Job number  310 added - Senior Data Analyst / Jr. Data Engineer
# Job number  311 added - Associate Machine Learning Engineer (Remote)
# Job number  312 added - Director Data Science
# Job number  313 added - Junior Machine Learning Engineer
# Job number  314 added - Senior Data Analyst
# Job number  315 added - VP, Data Science
# Job number  316 added - Lead Data Scientist, Managing Consultant - Cleared
# Job number  317 added - Data Scientist
# Job number  318 added - Data Scientist 5 - Experimentation & Causal Inference
# Job number  319 added - Data Scientist (Remote)
# Job number  320 added - Data Scientist, East
# Job number  321 added - Senior Data Scientist (Machine Learning)- Remote
# Job number  322 added - Senior Data Analyst
# Job number  323 added - Associate Data Scientist (Remote)
# Job number  324 added - Data Scientist - Marketing
# Job number  325 added - Data Scientist
# Job number  326 added - Network Data Scientist
# Job number  327 added - Data Scientist
# Job number  328 added - Data Scientist (Remote)
# Job number  329 added - Senior Data Scientist
# Job number  330 added - Data Scientist (Virtual)
# Job number  331 added - Senior Machine Learning Engineer – Document Intelligence
# Job number  332 added - Developer Relations (MLOps/ML/AI)
# Job number  333 added - Data Engineer I
# Job number  334 added - Senior Data Scientist-Tory Burch
# Job number  335 added - Machine Learning Engineer
# Job number  336 added - Senior Data Analyst
# Job number  337 added - Natural Language Processing (NLP) Engineer
# Job number  338 added - Senior Data Scientist, Bidder
# Job number  339 added - Statistician
# Job number  340 added - Data Scientist - HealthTech Algorithms
# Job number  341 added - Data Engineer, Junior
# Job number  342 added - Senior Data Analyst
# Job number  343 added - Head of Data Science
# Job number  344 added - Computer Vision Data Scientist
# Job number  345 added - Data Scientist
# Job number  346 added - Senior Data Analyst
# Job number  347 added - Sr. Data Scientist
# Job number  348 added - Data Scientist
# Job number  349 added - Data Scientist, Product Analytics
# Job number  350 added - Data Scientist - Fully remote
# Job number  351 added - Data Scientist - Risk
# Job number  352 added - Data Analyst
# Job number  353 added - Data Scientist
# Job number  354 added - Cost Analyst
# Job number  355 added - Staff Data Scientist, ML Ops
# Job number  356 added - Director of Trusted AI Product Management, Office of Data Science (remote)
# Job number  357 added - Data Scientist
# Job number  358 added - Senior Data Analyst
# Job number  359 added - Head of Machine Learning Engineer
# Job number  360 added - Machine Learning Engineer
# Job number  361 added - Marketing Data Scientist
# Job number  362 added - Data Scientist 2
# Job number  363 added - Lead Product Data Scientist
# Job number  364 added - Data Scientist training
# Job number  365 added - Embedded / Machine Learning Engineer
# Job number  366 added - Senior Data Analyst
# Job number  367 added - Senior Marketing Data Scientist
# Job number  368 added - Data Science Manager
# Job number  369 added - Machine Learning Specialist
# Job number  370 added - AI Engineer
# Job number  371 added - Senior Data Scientist
# Job number  372 added - Data Scientist
# Job number  373 added - Data Scientist/Data Analyst
# Job number  374 added - Data Scientist
# Job number  375 added - Data Scientist
# Job number  376 added - Senior Data Analyst
# Job number  377 added - Data Scientist
# Job number  378 added - Principal Data Scientist, Consumer Lending (Remote)
# Job number  379 added - Data Scientist
# Job number  380 added - Data Scientist
# Job number  381 added - Data Engineer with Machine learning Exp.
# Job number  382 added - Senior Machine Learning Engineer
# Job number  383 added - Sr. Data Analyst - Cyber Risk Management
# Job number  384 added - Data Scientist (Remote)
# Job number  385 added - Data Scientist
# Job number  386 added - Data Scientist - Model Validator (REMOTE)
# Job number  387 added - Ph.D. Consultants with Airtificial Intelligence and Machine Learning
# Job number  388 added - Senior Data Scientist (Remote)
# Job number  389 added - Senior Data Scientist II (REMOTE)
# Job number  390 added - Graduate Research Fellow, Machine Learning – Summer 2023
# Job number  391 added - Product Data Scientist
# Job number  392 added - Machine Learning Engineer
# Job number  393 added - Machine Learning Scientist
# Job number  394 added - Mathematical Engineer
# Job number  395 added - Software Engineering Manager, AI Team
# Job number  396 added - Senior Data Scientist
# Job number  397 added - Climate Risk Senior Data Scientist (remote)
# Job number  398 added - Machine Learning Engineer(MLOps)
# Job number  399 added - Data Scientist
# Job number  400 added - Senior Data Scientist
# Job number  401 added - Project Manager - Data Science / Data Analytics
# Job number  402 added - Data Specialist
# Job number  403 added - Data Scientist II
# Job number  404 added - Data Scientist - Remote
# Job number  405 added - Data Scientist (Remote Optional)
# Job number  406 added - Data Scientist
# Job number  407 added - Data Scientist (Remote)
# Job number  408 added - Data Scientist
# Job number  409 added - Data Scientist
# Job number  410 added - Manager, Data Science
# Job number  411 added - Machine Learning Engineer
# Job number  412 added - Principal Data Scientist (Remote)
# Job number  413 added - Staff Software Engineer, Machine Learning
# Job number  414 added - DevSecOps Engineer - AI -Start -Up (East Coast Remote)
# Job number  415 added - Senior Data Scientist
# Job number  416 added - Sr. Business Data Analyst
# Job number  417 added - Data Scientist, Product Analytics
# Job number  418 added - Statistician I
# Job number  419 added - Data Scientist
# Job number  420 added - Data Science Manager
# Job number  421 added - Sr Clinical Data Analyst
# Job number  422 added - Data Scientist, Advanced
# Job number  423 added - Senior Data Scientist (MDTF-P)
# Job number  424 added - Sr Prin Clin Data Scientist
# Job number  425 added - Director of Data Science
# Job number  426 added - Data Engineer/Data Scientist
# Job number  427 added - Data Scientist II
# Job number  428 added - Data Scientist - Compliance Consultant
# Job number  429 added - Senior Data Scientist
# Job number  430 added - Data Scientist
# Job number  431 added - Senior Data Analyst
# Job number  432 added - ML Engineer I
# Job number  433 added - Data Scientist
# Job number  434 added - Director of Data Science - Remote
# Job number  435 added - Data Architect (0652U) - Berkeley Institute for Data Science (BIDS) /CLEAN Initiative
# Job number  436 added - Machine Learning Scientist (Computer Vision)
# Job number  437 added - PhD Residency - AI/Machine Learning
# Job number  438 added - Senior Data Scientist
# Job number  439 added - Data Scientist
# Job number  440 added - Machine Learning Engineer
# Job number  441 added - Senior Data Scientist
# Job number  442 added - Senior Machine Learning Engineer
# Job number  443 added - Software Development Engineer, Robotics AI
# Job number  444 added - Risk Statistician
# Job number  445 added - Data Scientist
# Job number  446 added - Senior Data Scientist
# Job number  447 added - Senior Data Scientist- 100% Remote
# Job number  448 added - Conversation AI & Developer
# Job number  449 added - Senior Data Scientist (Full Stack)
# Job number  450 added - Data Scientist
# Job number  451 added - Data Science Engineer
# Job number  452 added - Data Scientist
# Job number  453 added - Data Scientist (Remote)
# Job number  454 added - Senior Data Scientist (Remote)
# Job number  455 added - Data Mining Specialist
# Job number  456 added - Senior Machine Learning Engineer
# Job number  457 added - Staff Data Scientist, Lonely Planet
# Job number  458 added - Data Science Graduate Research Assistant
# Job number  459 added - Senior Data Analyst
# Job number  460 added - Sr Data Analyst, Product
# Job number  461 added - Remote Data Scientist / Senior Data Scientist
# Job number  462 added - Senior Data Analyst
# Job number  463 added - Data Science Sol Consultant
# Job number  464 added - Software Engineer - Machine Learning
# Job number  465 added - VP, Data Science
# Job number  466 added - Cybersecurity Data Science Lead
# Job number  467 added - Sr. Machine Learning Engineer
# Job number  468 added - Machine Learning Engineer
# Job number  469 added - Machine Learning Engineer
# Job number  470 added - Sr. Data Scientist - Capital Modeling
# Job number  471 added - Staff Data Scientist - Retail
# Job number  472 added - Associate Machine Learning Engineer (Remote)
# Job number  473 added - Data Scientist
# Job number  474 added - Senior Data Scientist (Data Analytics)
# Job number  475 added - Senior/Principal Statistical Programmer (Remote)
# Job number  476 added - Data Scientist
# Job number  477 added - Machine Learning Engineer
# Job number  478 added - Sr. Energy Storage Machine Learning Engineer - REMOTE
# Job number  479 added - Director, Statistical Programming
# Job number  480 added - Principal Statistical Programmer FSP (Remote)
# Job number  481 added - Machine Learning Engineer Sr
# Job number  482 added - Senior Machine Learning Software Engineer - Remote
# Job number  483 added - Data Analyst
# Job number  484 added - Remote Data Scientist / Senior Data Scientist
# Job number  485 added - Java NLP Developer (14937)
# Job number  486 added - Senior Consultant, Data Analyst
# Job number  487 added - Sr. Data Scientist(ONLY W2)ro
# Job number  488 added - Sr Principal Data Engineer - Telecommute
# Job number  489 added - Data Scientist
# Job number  490 added - Data Scientist
# Job number  491 added - Senior Data Scientist
# Job number  492 added - Data Engineer/Data Scientist
# Job number  493 added - Data Scientist (Remote)
# Job number  494 added - Software Engineer, Machine Learning
# Job number  495 added - Machine Learning Lead Engineer/Scientist
# Job number  496 added - Principal Data Scientist - Sway AI
# Job number  497 added - Data Scientist Remote
# Job number  498 added - Senior Staff Data Scientist
# Job number  499 added - Head of Machine Learning
# Job number  500 added - Applied Scientist - AI Research
# Job number  501 added - Senior Product Data Scientist
# Job number  502 added - Manager/ Sr. Manager, Statistical Programming
# Job number  503 added - Senior Data Scientist - Search & Recommendation
# Job number  504 added - Senior Data Analyst
# Job number  505 added - Product Data Scientist, Bitcoin Wallet
# Job number  506 added - Senior Data Analyst, Supply Chain (Remote)
# Job number  507 added - Sr. Data Scientist REMOTE
# Job number  508 added - Data Scientist/Data Engineer (on W2)
# Job number  509 added - Applied Scientist
# Job number  510 added - Senior Data Scientist
# Job number  511 added - Data Scientist
# Job number  512 added - Senior Data Scientist
# Job number  513 added - Data Engineer
# Job number  514 added - Data Scientist
# Job number  515 added - Senior Data Scientist(Data Analytics)
# Job number  516 added - Software Engineer, Machine Learning Platform
# Job number  517 added - Machine Learning Scientist - NLP - Remote
# Job number  518 added - Data Science Lead
# Job number  519 added - Associate Fraud Intel Data Scientist (Remote)
# Job number  520 added - Statistical Genetic Analyst-Remote Hybrid
# Job number  521 added - Machine Learning operation Engineer
# Job number  522 added - Vitria Data Scientist
# Job number  523 added - AWS Data Architect
# Job number  524 added - Senior Data Scientist (R-12988)
# Job number  525 added - Principal (ML) Data Scientist
# Job number  526 added - Senior Data Scientist
# Job number  527 added - Machine Learning Research Group Lead
# Job number  528 added - Data Scientist
# Job number  529 added - Data Scientist II
# Job number  530 added - Senior Data Scientist (Remote)
# Job number  531 added - Machine Learning Engineer II
# Job number  532 added - Machine Learning Engineer
# Job number  533 added - Azure Data engineer
# Job number  534 added - Managing Data Scientist
# Job number  535 added - Data Scientist Senior (Remote)
# Job number  536 added - Machine Learning Engineer
# Job number  537 added - AI Engineer
# Job number  538 added - Staff Applied Scientist, Natural Language Processing
# Job number  539 added - AI Education Lead
# Job number  540 added - Data Science Product Owner (REMOTE)
# Job number  541 added - Data Science Engineer
# Job number  542 added - Sr. Data Analyst
# Job number  543 added - Data Analyst/Scientist
# Job number  544 added - Data Scientist (Remote US Only)
# Job number  545 added - Data Scientist
# Job number  546 added - Data Scientist-Mid
# Job number  547 added - Sr Data Analyst
# Job number  548 added - Data Scientist Manager (Remote/US)
# Job number  549 added - Senior Risk Data Scientist
# Job number  550 added - Machine Learning Engineer
# Job number  551 added - Director of Data Science
# Job number  552 added - Data Scientist, Credit Risk
# Job number  553 added - Data Scientist
# Job number  554 added - Data Scientist
# Job number  555 added - Machine Learning Scientist - Telecommute
# Job number  556 added - Director of Data Science Services and Analytics
# Job number  557 added - Senior Data Analyst
# Job number  558 added - Sr. Data Analyst
# Job number  559 added - Lead Data Scientist
# Job number  560 added - Sr. Data Analyst
# Job number  561 added - Senior Data Scientist - Walmart Fulfillment Services
# Job number  562 added - Senior Statistical Programmer
# Job number  563 added - Machine learning Engineer (full time)
# Job number  564 added - Data Scientist, Senior Associate: Carbon-Free Mobility Program
# Job number  565 added - Senior Data / ML Engineer
# Job number  566 added - Research Data Scientist
# Job number  567 added - Senior Data Scientist
# Job number  568 added - Student Assistant - Statistical Analyst (Remote)
# Job number  569 added - data scientist II
# Job number  570 added - CDC Data Scientist Fellowship
# Job number  571 added - Data Scientist
# Job number  572 added - Data Scientist - Club Analytics - Remote
# Job number  573 added - Senior Data Analyst
# Job number  574 added - Lead Data Scientist
# Job number  575 added - Sr Data Analyst
# Job number  576 added - Data Scientist
# Job number  577 added - Machine Learning Engineer
# Job number  578 added - Data Scientist
# Job number  579 added - Senior Data Scientist
# Job number  580 added - Staff/Principal Data Scientist, Ads Machine Learning
# Job number  581 added - Lead Azure Data Solution Architect - Remote - Fulltime
# Job number  582 added - Associate Data Scientist
# Job number  583 added - Data Science Analyst III - Digital and Technology Partners - Remote
# Job number  584 added - Senior Data Analyst
# Job number  585 added - Consulting Partner-Data Analytics
# Job number  586 added - Product Data Scientist (Senior and Staff Levels)
# Job number  587 added - SAP Data Intelligence Lead Developer
# Job number  588 added - Data Scientist I/II (Model Risk Management and Model Risk Validation)
# Job number  589 added - Remote AWS Data Engineer with Sagemaker
# Job number  590 added - Data Science Associate (Remote)
# Job number  591 added - Lead Machine Learning Engineer
# Job number  592 added - Senior Data Scientist
# Job number  593 added - Temp Statistical Programming Contractor
# Job number  594 added - Lead Data Scientist
# Job number  595 added - Senior Data Scientist (REMOTE)
# Job number  596 added - Data Scientist
# Job number  597 added - Data Science Engineer
# Job number  598 added - Machine Learning Engineer
# Job number  599 added - Sr. Data Scientist (Healthcare)
# Job number  600 added - Junior AI Engineer
# Job number  601 added - Coding Bootcamp Data Scientist (Virtual/Remote)
# Job number  602 added - Data Forensics Scientist
# Job number  603 added - Data Scientist
# Job number  604 added - Data Engineer
# Job number  605 added - Senior Data Analyst
# Job number  606 added - Data Scientist - (Staff Level)
# Job number  607 added - Data Analyst Sr, FCP - FINANCE
# Job number  608 added - Tensorflow ML Engineer - US Remote
# Job number  609 added - Senior Data Analyst
# Job number  610 added - Senior Manager, Clinical Pharmacology Machine Learning
# Job number  611 added - Senior Data Scientist
# Job number  612 added - AI Research Engineer, Skill Learning
# Job number  613 added - Staff / Principal Data Scientist
# Job number  614 added - Sr Healthcare Economics Data Analyst - Remote
# Job number  615 added - SR Data Scientist
# Job number  616 added - Data Scientist
# Job number  617 added - Data Scientist
# Job number  618 added - Associate Data Scientist (REMOTE)
# Job number  619 added - Data Scientist - SQL & Python Experience
# Job number  620 added - Associate Director, Statistical Programming
# Job number  621 added - Machine Learning Engineer - 1
# Job number  622 added - Senior Clinical Data Curator, Contractor
# Job number  623 added - Sr. Customer Product Data Scientist
# Job number  624 added - Senior Data Scientist
# Job number  625 added - Senior Machine Learning Engineer
# Job number  626 added - Senior Data Analyst
# Job number  627 added - Sr. BSA/AML Data Analyst
# Job number  628 added - Data Cloud Solutions Associate
# Job number  629 added - Junior Data Scientist-Remote
# Job number  630 added - Senior Data Scientist
# Job number  631 added - AI MLOps Engineer
# Job number  632 added - Data Scientist - Machine Learning Ops
# Job number  633 added - Principal Statistician
# Job number  634 added - AI Data Engineer
# Job number  635 added - ML/NLP/Data Engineer
# Job number  636 added - Data Scientist II / Senior Data Scientist
# Job number  637 added - ArborCount Data Technician
# Job number  638 added - Data Scientist (COVID Vaccine) (Remote)
# Job number  639 added - Data Scientist
# Job number  640 added - Senior Financial Data Analyst
# Job number  641 added - Senior Data Analyst
# Job number  642 added - Senior Machine Learning Engineer (2)
# Job number  643 added - Product Software Engineer - Machine Learning
# Job number  644 added - AI / Machine Learning Engineer
# Job number  645 added - Sr Principal Data Engineer - Telecommute
# Job number  646 added - Senior Product Data Scientist
# Job number  647 added - Data Scientist, Software Developer
# Job number  648 added - Applied Scientist - Text-To-Speech (TTS)
# Job number  649 added - AI/Machine Learning Engineer (100% Remote) DHS
# Job number  650 added - Machine Learning Engineer/MLOps Engineer (Remote)
# Job number  651 added - Data Scientist
# Job number  652 added - Sr Clinical Data Scientist- R
# Job number  653 added - Senior Data Scientist - Machine Learning
# Job number  654 added - Sr Data Analyst
# Job number  655 added - Data Analyst Senior - Indirect Auto (remote)
# Job number  656 added - Machine Learning Software Engineer II
# Job number  657 added - Java / NLP Developer
# Job number  658 added - Data Scientist
# Job number  659 added - Machine Learning Engineer
# Job number  660 added - Principal Data Scientist (Remote)
# Job number  661 added - Senior Data Scientist
# Job number  662 added - Data Scientist
# Job number  663 added - Data Scientist
# Job number  664 added - Senior Data Scientist
# Job number  665 added - Senior Data Analyst
# Job number  666 added - Cyber Data Scientist (50-111422)
# Job number  667 added - Sr. Data Scientist
# Job number  668 added - Senior Managed Care Data Analyst
# Job number  669 added - Sr. Data Scientist, Commercial Operations
# Job number  670 added - Associate Director, Statistics
# Job number  671 added - Senior Scientist, Data Science - Remote
# Job number  672 added - Senior Data Analyst
# Job number  673 added - Senior Data Scientist (Remote Based)
# Job number  674 added - Machine Learning Scientist - (Open from Asst to Director-Level) - (100% Remote Throughout US)
# Job number  675 added - Senior IT Data Analyst
# Job number  676 added - Head of Data
# Job number  677 added - Engineering Manager -US -East Coast -AI Startup
# Job number  678 added - Data Scientist
# Job number  679 added - Senior Data Scientist
# Job number  680 added - Senior data analyst
# Job number  681 added - Data Scientist, Data Quality Engineer
# Job number  682 added - Senior Data Scientist
# Job number  683 added - Machine Learning Engineer
# Job number  684 added - Manager, Statistical Programming
# Job number  685 added - Sr. Product Manager, AI Tools
# Job number  686 added - Sr. Data Analyst, Data Science
# Job number  687 added - Senior FRM Analyst – Actuarial or Data Scientist
# Job number  688 added - Senior Data Scientist - HealthTech Algorithms
# Job number  689 added - Customer Data Scientist
# Job number  690 added - Data Scientist
# Job number  691 added - Data Scientist
# Job number  692 added - Senior Data Analyst
# Job number  693 added - Sr. Data Scientist
# Job number  694 added - Data Analytics & Reporting Analyst
# Job number  695 added - Data Insights Editor
# Job number  696 added - Sports Injury Data Scientist, RWE Agile Analytics
# Job number  697 added - Senior Data Scientist | Bankrate
# Job number  698 added - Senior Data Scientist - Remote
# Job number  699 added - Sr. Digital Data Analyst – Remote
# Job number  700 added - Junior Software and Applications Programmer| AI/ML
# Job number  701 added - Senior Data Scientist
# Job number  702 added - Machine Learning Dev Ops Tech Lead
# Job number  703 added - Staff Machine Learning Software Engineer
# Job number  704 added - 100% Remote! Product Manager- Data Science/Optimization)
# Job number  705 added - Actuarial Data Scientist (Remote)
# Job number  706 added - Senior AI/ML (Machine Learning) Engineer
# Job number  707 added - Principal Machine Learning Scientist - Search & Recommendations
# Job number  708 added - Data Mining Analyst
# Job number  709 added - AI Engineer
# Job number  710 added - Sr. Data Scientist
# Job number  711 added - Statistical Programmer Contractor, SAS/R (Remote)
# Job number  712 added - Senior Data Scientist
# Job number  713 added - Senior Data Scientist
# Job number  714 added - Data Scientist, Product Optimization
# Job number  715 added - Data Scientist
# Job number  716 added - Sr. Data Scientist - Store and Omnichannel
# Job number  717 added - 22-122: Global Cloud Retrieval Scientist
# Job number  718 added - Data Scientist
# Job number  719 added - REMOTE Principal Data Scientist
# Job number  720 added - Machine Learning Engineer
# Job number  721 added - Machine Learning Engineer
# Job number  722 added - Senior Data Scientist
# Job number  723 added - GIS & Data Science Specialist
# Job number  724 added - Machine Learning Engineer
# Job number  725 added - Machine Learning Engineer
# Job number  726 added - Senior Machine Learning Engineer
# Job number  727 added - Senior Data Science Analyst
# Job number  728 added - Financial Crimes - Fraud Data Scientist - Manager
# Job number  729 added - Applied Machine Learning Scientist, Biology
# Job number  730 added - Sr. Machine Learning Engineer
# Job number  731 added - Business Performance Data Science Analyst
# Job number  732 added - eComm Principal Data Scientist
# Job number  733 added - Staff Software Engineer, Data Science
# Job number  734 added - Director, Data Science: Apollo Team (Remote-Eligible)
# Job number  735 added - Senior Data Scientist (Remote Based)
# Job number  736 added - ML Engineer
# Job number  737 added - Data De-Identification Data Analyst Senior Associate
# Job number  738 added - Data Scientist - NLP
# Job number  739 added - Machine Learning and AI Co-op
# Job number  740 added - Data Scientist - Role can be remote
# Job number  741 added - Senior Data Analyst
# Job number  742 added - Principal Applied Scientist - Machine Learning, SCOT - Fulfillment By Amazon
# Job number  743 added - Data Scientist (Remote)
# Job number  744 added - Data Scientist Machine Learning Engineer
# Job number  745 added - Data Scientist / Data Analyst
# Job number  746 added - Staff Data Scientist
# Job number  747 added - Consumer Credit Data Scientist (remote)
# Job number  748 added - Vice President, Health Policy - Evaluation, Economics and Predictive Modeling - Telecommute
# Job number  749 added - Senior Data Analyst (Remote)
# Job number  750 added - Senior Data Analyst (Risk & Compliance)
# Job number  751 added - Senior Data Analyst – Audit Analytics
# Job number  752 added - Lead ML Engineer - AI
# Job number  753 added - Senior Machine Learning Engineer, Planning & Prediction
# Job number  754 added - Remote Data Scientist / Senior Data Scientist
# Job number  755 added - Field Support Technical Specialist (m/f/d)
# Job number  756 added - Sr Principal Data Engineer - Telecommute
# Job number  757 added - Lead Data Analyst II
# Job number  758 added - Real World Data (RWD) Scientist
# Job number  759 added - Principal Statistician (Remote)
# Job number  760 added - Senior Staff Software Engineer, Machine Learning Platform
# Job number  761 added - Data Director
# Job number  762 added - Machine Learning Engineer
# Job number  763 added - Data Scientist Statistician
# Job number  764 added - Staff Data Scientist
# Job number  765 added - Data Scientist Mid-Level #1687
# Job number  766 added - Staff Fellow- Data Scientist
# Job number  767 added - Machine Learning Engineer
# Job number  768 added - Product Data Scientist
# Job number  769 added - Senior Data Analyst
# Job number  770 added - Machine Learning Engineer LEAD
# Job number  771 added - Climate Data Scientist
# Job number  772 added - Senior Data Scientist - Risk
# Job number  773 added - Data Analytics & Data Science Expert & Technical Coach - Part Time, Remote
# Job number  774 added - Applied ML Engineer
# Job number  775 added - Senior Data Analyst - Data Governance
# Job number  776 added - Senior Data Analyst
# Job number  777 added - Senior Machine Learning Engineer
# Job number  778 added - Principal Data Scientist - Machine Learning (remote)
# Job number  779 added - Senior Data Analyst (Remote)
# Job number  780 added - Manager of Manufacturing Analytics/ Data Science (Remote)
# Job number  781 added - Patent Agent / Patent Engineer / Software AI CS Computer
# Job number  782 added - Sr Software Engineer (AI) - Telecommute
# Job number  783 added - Senior Data Engineer with on-prem experience - 100% remote from anywhere is US
# Job number  784 added - Data Scientist
# Job number  785 added - Clinical Stat Programming Analyst
# Job number  786 added - Sr. Data Scientist
# Job number  787 added - Machine Learning Engineer
# Job number  788 added - Associate Director, Clinical Data Science, Spotfire/R (Remote)
# Job number  789 added - Software Engineer, Machine Learning Platform
# Job number  790 added - Data Scientist (HEOR / RWE)
# Job number  791 added - Data Analyst/Scientist
# Job number  792 added - Data Scientist. Team Lead.
# Job number  793 added - Staff Data Scientist (Remote, US)
# Job number  794 added - Senior Data Analyst - Accounting
# Job number  795 added - Principal Data Scientist (Remote Friendly)
# Job number  796 added - Data Analytics Engineer
# Job number  797 added - Sr. Data Scientist
# Job number  798 added - Senior Data Scientist
# Job number  799 added - Data Scientist, Level II
# Job number  800 added - Graduate IT Program - Information Technology, Cybersecurity and Data Science (Remote)
# Job number  801 added - Data Scientist
# Job number  802 added - Healthcare Data Science Consultant
# Job number  803 added - Biomarker Statistical Programmer
# Job number  804 added - Machine Learning Engineer
# Job number  805 added - Senior Data Scientist - Analytics (Remote)
# Job number  806 added - Director, Product
# Job number  807 added - Lead Data Scientist
# Job number  808 added - Applied Data Scientist
# Job number  809 added - Senior Data Analyst (Game)
# Job number  810 added - Clinical Data Science/Programming Engineer-1
# Job number  811 added - Program Integrity Data Scientist
# Job number  812 added - Senior Data Scientist
# Job number  813 added - Senior Data Scientist
# Job number  814 added - Machine Learning Engineer
# Job number  815 added - Staff Data Scientist
# Job number  816 added - Lead Data Scientist
# Job number  817 added - Lead Applied Data Scientist
# Job number  818 added - Sr Data Scientist
# Job number  819 added - Senior Data Scientist
# Job number  820 added - Senior Data Scientist
# Job number  821 added - Data Scientist IV Data Science - 100% remote from any approved KP location!
# Job number  822 added - Sr Data Scientist
# Job number  823 added - Senior Data Analyst - Product
# Job number  824 added - Data Scientist 2 (Remote)
# Job number  825 added - Data Scientist II
# Job number  826 added - Data Scientist
# Job number  827 added - Sr. Data Analyst
# Job number  828 added - Senior Data Scientist
# Job number  829 added - Data Scientist
# Job number  830 added - Senior Data Analyst
# Job number  831 added - Data Scientist
# Job number  832 added - Senior Machine Learning Engineer – AI/ML (Remote Option*)
# Job number  833 added - Segmentation Data Scientist
# Job number  834 added - Senior Staff Data Scientist
# Job number  835 added - Sr. Azure/Artificial Intelligence/Machine Learning Consultant

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()

import random

async def get_description(urls):
  descriptions = []
  async with get_session(Geckodriver(binary=driver_path, log_file=asyncio.subprocess.PIPE), Firefox(**options)) as session:
    for url in urls:
      await session.get("https://www.indeed.com"+url)
      jd = await session.get_element('#jobDescriptionText')
      descriptions.append(await jd.get_text())
      await asyncio.sleep(random.random() * 1.5)
  return descriptions

## Number of browser instances to use
n = 3

tasks = [asyncio.create_task(get_description(urls)) for urls in np.array_split(Links_list, n)]
dataframe['Descriptions'] = [desc for task in tasks for desc in await task]

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                                       Data Scientist
# 1          Data Scientist, Marketing & Online (Remote)
# 2                              Analyst I, Data Science
# 3                              Data Scientist (Remote)
# 4                                 Data Scientist - NLP
# ..                                                 ...
# 830                  Director, Statistical Programming
# 831      Principal Statistical Programmer FSP (Remote)
# 832  Senior Machine Learning Software Engineer - Re...
# 833      Remote Data Scientist / Senior Data Scientist
# 834                         Java NLP Developer (14937)
#
#                          Company                                   Location  \
# 0    Shaw Industries Group, Inc.                                     Remote
# 1                 The Home Depot                Remote in Atlanta, GA 30361
# 2       Liberty Mutual Insurance                                     Remote
# 3                           Yelp                                     Remote
# 4                    Ursus, Inc.             Remote in Menlo Park, CA 94025
# ..                           ...                                        ...
# 830      Firma Clinical Research                                     Remote
# 831                      Labcorp  Remote in Wilmington, NC 28403+1 location
# 832                      Dropbox      Remote in Boston, MA 02108+1 location
# 833        Direct Auto Insurance          Remote in Winston-Salem, NC 27103
# 834               The Baer Group        Remote in Washington, DC+1 location
#
#     Rating                       Date                     Salary  \
# 0      3.8   PostedPosted 14 days ago                        NaN
# 1      3.7                PostedToday  $90,000 - $160,000 a year
# 2      3.6    PostedPosted 9 days ago  $70,100 - $161,600 a year
# 3      3.4  PostedPosted 30+ days ago  $96,000 - $220,000 a year
# 4      4.9   PostedPosted 12 days ago    $40.00 - $48.65 an hour
# ..     ...                        ...                        ...
# 830    3.8    PostedPosted 6 days ago                        NaN
# 831    3.4    PostedPosted 6 days ago                        NaN
# 832    3.9    PostedPosted 6 days ago                        NaN
# 833    3.0  PostedPosted 30+ days ago                        NaN
# 834    4.2    PostedPosted 6 days ago                        NaN
#
#                                            Description  \
# 0    Partner with data scientists across the enterp...
# 1    55% Solution Development - Design and develop ...
# 2    Competencies typically acquired through a Mast...
# 3    Communicate key insights from analyses, experi...
# 4    " Apply knowledge of statistics, machine learn...
# ..                                                 ...
# 830  Career Opportunity – Director Statistical Prog...
# 831  Hiring for Principal Statistical Programmer FS...
# 832  Role Description Dropbox is looking for a Mach...
# 833  **Remote work available** Job Summary: This ro...
# 834  **Federal Projects - Applicant must be a Unite...
#
#                                                  Links  \
# 0    /pagead/clk?mo=r&ad=-6NYlbfkN0CrvEjiI1EGEnRdQc...
# 1    /pagead/clk?mo=r&ad=-6NYlbfkN0BAuTfAu5ThYozS55...
# 2    /pagead/clk?mo=r&ad=-6NYlbfkN0D19kSVUiNzG2UWy1...
# 3    /rc/clk?jk=0072004f2d3180a4&fccid=0e94073a1c93...
# 4    /pagead/clk?mo=r&ad=-6NYlbfkN0CT8vBT9H5mqECx2d...
# ..                                                 ...
# 830  /pagead/clk?mo=r&ad=-6NYlbfkN0Ccr8WjSa4DbpNgRF...
# 831  /pagead/clk?mo=r&ad=-6NYlbfkN0DPts0BZf5RUYLDzn...
# 832  /pagead/clk?mo=r&ad=-6NYlbfkN0BXuQyu8a89IGjYOq...
# 833  /pagead/clk?mo=r&ad=-6NYlbfkN0ABn5GwwiAtE4UwcQ...
# 834  /pagead/clk?mo=r&ad=-6NYlbfkN0Bt5MV-4xXS8zaIXZ...
#
#                                           Descriptions
# 0    We are looking for a data scientist to join ou...
# 1    Position Purpose:\nThe Data Scientist is respo...
# 2    The Product Design and Modeling Department of ...
# 3    At Yelp, it’s our mission to connect people wi...
# 4    JOB TITLE: Data Scientist - NLP\nLOCATION: Rem...
# ..                                                 ...
# 830  Career Opportunity – Director Statistical Prog...
# 831  Hiring for Principal Statistical Programmer FS...
# 832  Role Description Dropbox is looking for a Mach...
# 833  **Remote work available**\n\nJob Summary:\nThi...
# 834  **Federal Projects - Applicant must be a Unite...
#
# [835 rows x 9 columns]
