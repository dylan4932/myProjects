# %%
import pandas as pd

df1 = pd.read_csv('27.csv')
df2 = pd.read_csv('28.csv')
df3 = pd.read_csv('29.csv')
df4 = pd.read_csv('30.csv')
df5 = pd.read_csv('31.csv')

# %%
data = pd.concat([df1, df2, df3, df4, df5]).drop_duplicates()

# %%
len(data)
data.to_csv('a3_jobs.csv', index=False)

# %%
data
# Out:
#                                           Title  \
# 0                           Senior Data Analyst
# 1                              Business Analyst
# 2                              Business Analyst
# 3     REMOTE Project-based roles - Data Analyst
# 4                 Credit Risk Analyst - Korean*
# ...                                         ...
# 1062                           Business Analyst
# 1063                         Settlement Analyst
# 1075                       COST PRICING ANALYST
# 1090                       COST PRICING ANALYST
# 1105                       COST PRICING ANALYST
#
#                                     Company                     Location  \
# 0                                   Spinify                  Toronto, ON
# 1                         Eperformance Inc.  Hybrid remote in Ottawa, ON
# 2     Russell Hendrix Foodservice Equipment            +1 locationRemote
# 3                                  Deloitte        Remote in Toronto, ON
# ...
