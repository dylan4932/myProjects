# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
# driver_path = "./drivers/windows/geckodriver.exe"
# Linux
driver_path = r"./drivers/geckodriver"
# driver = webdriver.Firefox(executable_path=driver_path)
# driver = webdriver.Chrome(executable_path=driver_path)
driver = webdriver.Chrome()

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data analyst"
## Enter a location (City, State or Zip or remote)
locations = "Canada"

def get_url(position, location):
    url_template = "https://ca.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 200

jn= 0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')

    for job in jobs:
        result_html = job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')
        
        jn += 1
        
        liens = job.find_elements(By.TAG_NAME, "a")
        links = liens[0].get_attribute("href")
        
        title = soup.select('.jobTitle')[0].get_text().strip()
        company = soup.select('.companyName')[0].get_text().strip()
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
       
        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Job number    1 added - Senior Data Analyst
# Job number    2 added - Business Analyst
# Job number    3 added - Business Analyst
# Job number    4 added - REMOTE Project-based roles - Data Analyst
# Job number    5 added - Credit Risk Analyst - Korean*
# Job number    6 added - Data Analytics and Reporting Analyst
# Job number    7 added - Data analyst student
# Job number    8 added - Business Analyst
# Job number    9 added - Data Analyst Intern
# Job number   10 added - Junior Data Support Analyst
# Job number   11 added - Data Analyst
# Job number   12 added - HR Systems Business Analyst - HYBRID
# Job number   13 added - Data Analyst
# Job number   14 added - Climate Data Analyst
# Job number   15 added - Data Operations Analyst (Remote)
# Job number   16 added - Data Analyst
# Job number   17 added - Data Analyst
# Job number   18 added - Data Analyst, Competitive Intelligence
# Job number   19 added - Junior Business Analyst (remote)
# Job number   20 added - Data Analyst - Data & Analytics
# Job number   21 added - RESEARCH ANALYST 1
# Job number   22 added - HR Systems Business Analyst - HYBRID
# Job number   23 added - CLAIMS ANALYST
# Job number   24 added - Data Analyst
# Job number   25 added - DATA MANAGEMENT & REPORTING ANALYST
# Job number   26 added - Analyst, Liquidity Reporting & Analysis
# Job number   27 added - Budget Analyst
# Job number   28 added - Data Visualization Analyst
# Job number   29 added - Data Analyst
# Job number   30 added - Shopper Insights Analyst Intern
# Job number   31 added - BUSINESS ANALYST CORPORATE SERVICES
# Job number   32 added - Microbiology Analyst (Inventory) - AMENDMENT
# Job number   33 added - Data Analyst Intern
# Job number   34 added - Data Analyst
# Job number   35 added - market research analyst
# Job number   36 added - Operations Analyst Intern (Data & BI) - Summer 2023
# Job number   37 added - Data Analyst
# Job number   38 added - Analyst, FinOps
# Job number   39 added - Smart Growth (Spatial Research) Analyst
# Job number   40 added - Data Analyst (Data Management and Systems Integration Specialist).
# Job number   41 added - Manulife GWAM Operations Analyst New Graduate Program
# Job number   42 added - Data Analyst
# Job number   43 added - Data Analyst
# Job number   44 added - Data Analyst
# Job number   45 added - Loyalty Analyst
# Job number   46 added - Data Analyst
# Job number   47 added - Statistical Analyst - Data Science
# Job number   48 added - Crime Analyst
# Job number   49 added - Text Data Analyst
# Job number   50 added - Data Analyst
# Job number   51 added - Climate & Energy Analyst
# Job number   52 added - Analyst, Economic Advisory (Across Canada)
# Job number   53 added - market research analyst
# Job number   54 added - Business and Data Analyst
# Job number   55 added - Data analyst
# Job number   56 added - Planning Analyst
# Job number   57 added - Data Entry/Analyst
# Job number   58 added - database analyst
# Job number   59 added - Market Data Analyst
# Job number   60 added - Data Analyst
# Job number   61 added - Business Data Analyst
# Job number   62 added - WFM Reporting Analyst
# Job number   63 added - Developer/Data Analyst
# Job number   64 added - Reporting Analyst
# Job number   65 added - Senior Analyst Data & Analytics
# Job number   66 added - Analyst, Credit Risk
# Job number   67 added - Customer Success Analyst
# Job number   68 added - Data Analyst
# Job number   69 added - Data and Reporting Analyst
# Job number   70 added - Data Analyst, Equity, Diversity and Inclusion
# Job number   71 added - Analyst III
# Job number   72 added - Data Analyst
# Job number   73 added - Underwriting Analyst, PropertyOperations
# Job number   74 added - Data Analyst (Go-To-Market)
# Job number   75 added - Business Analyst
# Job number   76 added - Marketing Data Analyst
# Job number   77 added - Business Analyst
# Job number   78 added - Data Migration Analyst
# Job number   79 added - Data Analyst
# Job number   80 added - Associate Data Analyst
# Job number   81 added - Innovation and Data Analyst
# Job number   82 added - Senior Analyst, Data and Technology
# Job number   83 added - Sr. Data Analyst
# Job number   84 added - Senior Policy Analyst
# Job number   85 added - Data Catalog Analyst
# Job number   86 added - Data Analyst
# Job number   87 added - Credit Analyst
# Job number   88 added - Data Analyst
# Job number   89 added - Senior Analyst, Project Management
# Job number   90 added - Business Analyst
# Job number   91 added - Senior Analyst, Project Management
# Job number   92 added - Analyst, Operations Data Integrity (Volume)
# Job number   93 added - Business Intelligence Analyst Intern (Summer)
# Job number   94 added - Analyst, Fulfillment Planning (Toronto, ON)
# Job number   95 added - Data Analyst - Pipeline
# Job number   96 added - Analyst, Advance Analytics
# Job number   97 added - analyst, database
# Job number   98 added - Fraud Strategy Analyst, Summer 2023 (Co-op/Internship) - 4 months
# Job number   99 added - database analyst
# Job number  100 added - Reporting Analyst
# Job number  101 added - Data Analyst
# Job number  102 added - Junior Business Intelligence Analyst
# Job number  103 added - Database Analyst
# Job number  104 added - FinOps Analyst
# Job number  105 added - Quantitative Analyst
# Job number  106 added - Junior Business Systems Analyst
# Job number  107 added - Business Analyst 3
# Job number  108 added - Data Analyst
# Job number  109 added - Research Analyst NEW
# Job number  110 added - Category Analyst
# Job number  111 added - GIS Data Analyst
# Job number  112 added - Data Analyst
# Job number  113 added - Exceptions Analyst
# Job number  114 added - Workplace Wellbeing Data and Evaluation Analyst
# Job number  115 added - Junior Business Analyst
# Job number  116 added - Data Analyst
# Job number  117 added - Senior Data Analyst
# Job number  118 added - IT Data Analyst III
# Job number  119 added - Pyxis Analyst Intern
# Job number  120 added - Junior Business Analyst (Summer Student)
# Job number  121 added - Database Analyst
# Job number  122 added - market intelligence analyst
# Job number  123 added - Data Analyst (2023 Summer Intern)
# Job number  124 added - Data Analyst
# Job number  125 added - Data Analyst
# Job number  126 added - Quantitative Analyst
# Job number  127 added - Survey Data Analyst
# Job number  128 added - Business Analyst
# Job number  129 added - Upstream Solutions - Data Transformation Analyst (2023 Summer Intern)
# Job number  130 added - Reporting Analyst
# Job number  131 added - Facility Analyst
# Job number  132 added - database analyst
# Job number  133 added - Data Analyst
# Job number  134 added - Data Analyst, Health Surveillance
# Job number  135 added - Marketing Project Analyst, Campaign Operations
# Job number  136 added - Data Analyst, Health Surveillance
# Job number  137 added - Data Analyst
# Job number  138 added - Data Analyst
# Job number  139 added - Data Analyst
# Job number  140 added - Information Systems Analyst and Consultants
# Job number  141 added - Analyst - Data Strategy and Analytics
# Job number  142 added - Business Analyst (8-month Term)
# Job number  143 added - Data and BI Analyst
# Job number  144 added - database analyst
# Job number  145 added - Corporate Sustainability Analyst
# Job number  146 added - Business Systems Analyst I
# Job number  147 added - Data Analyst (Power BI) - REMOTE
# Job number  148 added - Service Quality Analyst
# Job number  149 added - Business Data Analyst - Co-op
# Job number  150 added - Data Analyst
# Job number  151 added - Senior Analyst, Performance Reporting
# Job number  152 added - Analyst, Optimization
# Job number  153 added - Global Strategic Insights Analyst
# Job number  154 added - Initiative - Reporting Analyst, Digital Hub
# Job number  155 added - Database Analyst (NOC-21223)
# Job number  156 added - database analyst
# Job number  157 added - New Ventures Strategy Analyst - Master Student
# Job number  158 added - PI Data Analyst
# Job number  159 added - Research & Data Analyst
# Job number  160 added - Crop Data Analyst
# Job number  161 added - Senior Business Analyst - TELUS Health - Pharmacy
# Job number  162 added - Business Data Analyst
# Job number  163 added - database analyst
# Job number  164 added - Senior Data Analyst (Product Analytics)
# Job number  165 added - Operations Analyst
# Job number  166 added - Analyst, Output Services
# Job number  167 added - Customer Business Analyst - Walmart
# Job number  168 added - Product Data Analyst
# Job number  169 added - ServiceNow Business Analyst
# Job number  170 added - Data Analyst – Coder - Decision Support - Regular Full-time (230136)
# Job number  171 added - Business Metrics Analyst
# Job number  172 added - Data Analyst
# Job number  173 added - Data Analyst
# Job number  174 added - Data Management Analyst
# Job number  175 added - Technical Business Analyst (remote)
# Job number  176 added - Data Specialist/Analyst
# Job number  177 added - Data Analyst
# Job number  178 added - Product Analyst
# Job number  179 added - Data Analyst
# Job number  180 added - Senior Data & Reporting Analyst
# Job number  181 added - Business Analyst – EDI
# Job number  182 added - Technical Data Analyst Specialist, Capital Markets Technology, Hybrid
# Job number  183 added - Policy Analyst
# Job number  184 added - Business Intelligence Analyst
# Job number  185 added - Policy Analyst
# Job number  186 added - Data Analyst – Healthcare Supply Chain
# Job number  187 added - Quality Improvement and Data Analyst
# Job number  188 added - Business Analyst
# Job number  189 added - Analyst, Data and Analytics - Data Strategy
# Job number  190 added - Research Analyst
# Job number  191 added - Supply Chain Analyst, 14-month Contract
# Job number  192 added - database analyst
# Job number  193 added - Senior Data Analyst
# Job number  194 added - Institutional Research & Data Analyst
# Job number  195 added - Analyst, Service Management
# Job number  196 added - Business Analyst
# Job number  197 added - Business Analyst
# Job number  198 added - Data Analyst
# Job number  199 added - Category Leadership Analyst
# Job number  200 added - Digital Analyst - GTM/Data Layer
# Job number  201 added - Data Analyst, Internal Audit
# Job number  202 added - Business Systems Analyst
# Job number  203 added - database analyst
# Job number  204 added - Actuarial Analyst
# Job number  205 added - database analyst
# Job number  206 added - Data Engineering Analyst - Hybrid
# Job number  207 added - ST-Analyst, Data Analytics & Reporting (8-12 months, Summer 2023, co-op student)
# Job number  208 added - ON-CHEC Cybersecurity Analyst
# Job number  209 added - Data Programmer Analyst
# Job number  210 added - Marketing Data Analyst - Remote in Canada except Quebec
# Job number  211 added - Reinsurance Analyst
# Job number  212 added - Research Analyst
# Job number  213 added - Market Research Analyst
# Job number  214 added - Analyste de données économique // Economy Data Analyst
# Job number  215 added - Summer 2023 Co-op:Data Analyst (Access Deployment Management Technical Support)
# Job number  216 added - Inventory Control Analyst
# Job number  217 added - Master Data Analyst, Data and BOM
# Job number  218 added - Senior Reporting and Data Analyst
# Job number  219 added - Business Analyst
# Job number  220 added - BUSINESS ANALYST, CUSTOMER OPERATIONS
# Job number  221 added - Data Engineer/Analyst
# Job number  222 added - WCM / Data Analyst
# Job number  223 added - Employer Data Analyst (Pensions)
# Job number  224 added - Data Analyst
# Job number  225 added - Data Analyst, Hotel Property activation
# Job number  226 added - Analyst
# Job number  227 added - Analyst-Total Rewards
# Job number  228 added - Data Analyst (Pyspark and Snowflake)
# Job number  229 added - database analyst
# Job number  230 added - Trade Operations Analyst
# Job number  231 added - Data Analyst
# Job number  232 added - Intern (4, 8 or 12 month) - Data Analyst
# Job number  233 added - Workforce Analyst - 9 Month Contract
# Job number  234 added - Business Analyst, Reporting
# Job number  235 added - Market Data Analyst -Fixed Income
# Job number  236 added - Data Analyst
# Job number  237 added - Business Intelligence Analyst, Experience@Siemens
# Job number  238 added - Business Analyst - Incident Data (remote)
# Job number  239 added - Senior Business Analyst - Tangerine
# Job number  240 added - Operations Business Analyst II
# Job number  241 added - Business Analyst
# Job number  242 added - Business Analyst (1 Year Contract)
# Job number  243 added - ILI Data Analyst II
# Job number  244 added - database analyst
# Job number  245 added - Business Systems Analyst - Hybrid
# Job number  246 added - database analyst
# Job number  247 added - database analyst
# Job number  248 added - Data and Analytics Analyst – Summer Student
# Job number  249 added - Data Analyst & Auto SPT Co-op
# Job number  250 added - Procurement Analyst
# Job number  251 added - Business Compliance Analyst I
# Job number  252 added - Decision Intelligence Analyst - PFT
# Job number  253 added - database analyst
# Job number  254 added - Sales Analyst
# Job number  255 added - Senior Business Strategy Analyst
# Job number  256 added - Business Analyst
# Job number  257 added - Junior Business Systems Analyst
# Job number  258 added - Junior Data Analyst - Consultant
# Job number  259 added - Business Analyst
# Job number  260 added - Data Analyst
# Job number  261 added - Data Analyst and Reporting Tools Developer
# Job number  262 added - INVENTORY MANAGEMENT ANALYST
# Job number  263 added - Data Analyst
# Job number  264 added - Senior Analyst, Data Engineering
# Job number  265 added - Business Systems Analyst
# Job number  266 added - data analyst - informatics and systems
# Job number  267 added - Business Analyst, Customer Service and Experience
# Job number  268 added - Corporate Energy Analyst
# Job number  269 added - Customer Insights Analyst
# Job number  270 added - Summer 2023 Co-op: Business & Data Analyst
# Job number  271 added - Business Analyst - Level 3
# Job number  272 added - Business Data Analyst (12 Month Contract)
# Job number  273 added - GIS Analyst (Hybrid/Remote)
# Job number  274 added - Junior Asset Management Consultant and Data Analyst
# Job number  275 added - Business Transformation Analyst (Intern)
# Job number  276 added - Data Governance Senior Analyst - Hybrid
# Job number  277 added - Market Data Analyst
# Job number  278 added - Category Analyst
# Job number  279 added - Business Analyst
# Job number  280 added - Product Analyst II
# Job number  281 added - database analyst
# Job number  282 added - Data Analyst (Exadata & Hadoop) - Remote
# Job number  283 added - Implementation Analyst
# Job number  284 added - Lead Data Analyst
# Job number  285 added - SR BUSINESS ANALYST
# Job number  286 added - Junior Data & Reporting Analyst, Mortgage Valuations (Co-op)
# Job number  287 added - Service Performance Research Analyst- AMENDMENT
# Job number  288 added - Database Quality Control Analyst
# Job number  289 added - Inventory Analyst - GTA
# Job number  290 added - analyst, database
# Job number  291 added - Data and Reporting Analyst with Computer Science background (VBA &DAX ) 1 year contract, New Grad Immediate start
# Job number  292 added - Data Business Analyst
# Job number  293 added - Business System Analyst
# Job number  294 added - Senior Analyst Data & Analytics
# Job number  295 added - Emergency Management Analyst
# Job number  296 added - Business Analyst with Regulatory
# Job number  297 added - Information Analyst
# Job number  298 added - Senior Data Analyst, Foundry
# Job number  299 added - Trade Desk Support Analyst, Summer 2023 (Co-op/Internship) - 4 months
# Job number  300 added - Inventory Analyst

# %%
driver.quit()

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
import random
import time

# %%
driver = webdriver.Chrome()
descriptions=[]
for i in Links_list:
        driver.get(i)
        driver.implicitly_wait(random.randint(3, 8))
        try:
            jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
            descriptions.append(jd)
        except Exception:
            descriptions.append('n/a')
            pass
        time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions

# %%
driver.quit()

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                                  Title  \
# 0                                  Senior Data Analyst
# 1                                     Business Analyst
# 2                                     Business Analyst
# 3            REMOTE Project-based roles - Data Analyst
# 4                        Credit Risk Analyst - Korean*
# ..                                                 ...
# 295                   Business Analyst with Regulatory
# 296                                Information Analyst
# 297                       Senior Data Analyst, Foundry
# 298  Trade Desk Support Analyst, Summer 2023 (Co-op...
# 299                                  Inventory Analyst
#
#                                    Company                     Location  \
# 0                                  Spinify                  Toronto, ON
# 1                        Eperformance Inc.  Hybrid remote in Ottawa, ON
# 2    Russell Hendrix Foodservice Equipment            +1 locationRemote
# 3                                 Deloitte        Remote in Toronto, ON
# 4                     KEB Hana Bank Canada               North York, ON
# ..                                     ...                          ...
# 295                 Software International                  Toronto, ON
# 296                     Canadian Red Cross                       Remote
# 297                  Providence Healthcare                Vancouver, BC
# 298                    BMO Financial Group                  Toronto, ON
# 299                  Legrand North America              Scarborough, ON
#
#     Rating                       Date                   Salary  \
# 0      NaN  EmployerActive 4 days ago  $90,000–$110,000 a year
# 1      NaN  EmployerActive 2 days ago   $60,000–$80,000 a year
# 2      2.6  PostedPosted 30+ days ago                      NaN
# 3      3.9   PostedPosted 17 days ago                      NaN
# 4      3.1     PostedPosted 1 day ago                      NaN
# ..     ...                        ...                      ...
# 295    NaN  PostedPosted 30+ days ago              $60 an hour
# 296    3.9  PostedPosted 30+ days ago   $61,382–$78,216 a year
# 297    4.0     PostedPosted 1 day ago                      NaN
# 298    3.8    PostedPosted 9 days ago                      NaN
# 299    3.6  PostedPosted 30+ days ago                      NaN
#
#                                            Description  \
# 0    3+ years of experience in data analysis, prefe...
# 1    Design business processes and data flows betwe...
# 2    You have strong analytical skills with ability...
# 3    In addition, for this particular data analyst ...
# 4    Reviews anomalies of the data outputs indicate...
# ..                                                 ...
# 295  Experience with Finance Reporting projects wit...
# 296  Ensure system and data integrity.\nExpertise i...
# 297  Oversees data analytics requests and reporting...
# 298  Analyzes data and information to provide insig...
# 299  This role will be responsible for maintaining ...
#
#                                                  Links  \
# 0    https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 1    https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 2    https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 3    https://ca.indeed.com/rc/clk?jk=ad5ed76a4a1a89...
# 4    https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# ..                                                 ...
# 295  https://ca.indeed.com/rc/clk?jk=65617b01fb8ee0...
# 296  https://ca.indeed.com/rc/clk?jk=e69da81cb3e0c5...
# 297  https://ca.indeed.com/rc/clk?jk=d0fd9e23936c96...
# 298  https://ca.indeed.com/rc/clk?jk=362cdf0df92369...
# 299  https://ca.indeed.com/rc/clk?jk=31c0303bcb340e...
#
#                                           Descriptions
# 0    About us\nSpinify is a dynamic and innovative ...
# 1    Eperformance Inc. is a solutions and services ...
# 2    Russell Hendrix is looking to add a Business A...
# 3    Job Type: Independent Contractor\nReference co...
# 4    Job Title: Credit Risk Analyst\nDept./Br.: Cre...
# ..                                                 ...
# 295  Our company Software International (SI) suppli...
# 296  Title: Information Analyst\nLocation: Remote\n...
# 297  Article Flag: Mandatory Vaccination Please Not...
# 298  100 King Street West Toronto Ontario,M5X 1A1\n...
# 299  Position Description:\nAt a Glance\n\nLegrand ...
#
# [300 rows x 9 columns]
